# %% [markdown]
# ## CSV file

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# read csv file
df = pd.read_csv('kalimati_tarkari.csv')
print(df)
# Out:
#             SN            Commodity        Date Unit  Minimum  Maximum  \
# 0            0   Tomato Big(Nepali)  2013-06-16   Kg       35       40
# 1            1  Tomato Small(Local)  2013-06-16   Kg       26       32
# 2            2           Potato Red  2013-06-16   Kg       20       21
# 3            3         Potato White  2013-06-16   Kg       15       16
# 4            4   Onion Dry (Indian)  2013-06-16   Kg       28       30
# ...        ...                  ...         ...  ...      ...      ...
# 197156  197156    Garlic Dry Nepali  2021-05-13   Kg      100      120
# 197157  197157     Fish Fresh(Rahu)  2021-05-13   KG      270      280
# 197158  197158  Fish Fresh(Bachuwa)  2021-05-13   KG      225      235
# 197159  197159   Fish Fresh(Chhadi)  2021-05-13   KG      220      230
# 197160  197160  Fish Fresh(Mungari)  2021-05-13   KG      240      250
#
#         Average
# 0          37.5
# 1          29.0
# 2          20.5
# 3          15.5
# 4          29.0
# ...

# %%
# first five data
df.head()
# Out:
#    SN            Commodity        Date Unit  Minimum  Maximum  Average
# 0   0   Tomato Big(Nepali)  2013-06-16   Kg       35       40     37.5
# 1   1  Tomato Small(Local)  2013-06-16   Kg       26       32     29.0
# 2   2           Potato Red  2013-06-16   Kg       20       21     20.5
# 3   3         Potato White  2013-06-16   Kg       15       16     15.5
# 4   4   Onion Dry (Indian)  2013-06-16   Kg       28       30     29.0

# %%
# first 10 data
df.head(10)
# Out:
#    SN             Commodity        Date Unit  Minimum  Maximum  Average
# 0   0    Tomato Big(Nepali)  2013-06-16   Kg       35       40     37.5
# 1   1   Tomato Small(Local)  2013-06-16   Kg       26       32     29.0
# 2   2            Potato Red  2013-06-16   Kg       20       21     20.5
# 3   3          Potato White  2013-06-16   Kg       15       16     15.5
# 4   4    Onion Dry (Indian)  2013-06-16   Kg       28       30     29.0
# 5   5         Carrot(Local)  2013-06-16   Kg       30       35     32.5
# 6   6        Cabbage(Local)  2013-06-16   Kg        6       10      8.0
# 7   7           Cauli Local  2013-06-16   Kg       30       35     32.5
# 8   8           Raddish Red  2013-06-16   Kg       35       40     37.5
# 9   9  Raddish White(Local)  2013-06-16   Kg       25       30     27.5

# %%
# last five data
df.tail()
# Out:
#             SN            Commodity        Date Unit  Minimum  Maximum  \
# 197156  197156    Garlic Dry Nepali  2021-05-13   Kg      100      120
# 197157  197157     Fish Fresh(Rahu)  2021-05-13   KG      270      280
# 197158  197158  Fish Fresh(Bachuwa)  2021-05-13   KG      225      235
# 197159  197159   Fish Fresh(Chhadi)  2021-05-13   KG      220      230
# 197160  197160  Fish Fresh(Mungari)  2021-05-13   KG      240      250
#
#         Average
# 197156    110.0
# 197157    275.0
# 197158    230.0
# 197159    225.0
# 197160    245.0

# %%
# information about the data
# info() tells about number of null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197161 entries, 0 to 197160
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   SN         197161 non-null  int64
#  1   Commodity  197161 non-null  object
#  2   Date       197161 non-null  object
#  3   Unit       197161 non-null  object
#  4   Minimum    197161 non-null  int64
#  5   Maximum    197161 non-null  int64
#  6   Average    197161 non-null  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 10.5+ MB

# %%
# convert date
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#             SN            Commodity       Date Unit  Minimum  Maximum  Average
# 0            0   Tomato Big(Nepali) 2013-06-16   Kg       35       40     37.5
# 1            1  Tomato Small(Local) 2013-06-16   Kg       26       32     29.0
# 2            2           Potato Red 2013-06-16   Kg       20       21     20.5
# 3            3         Potato White 2013-06-16   Kg       15       16     15.5
# 4            4   Onion Dry (Indian) 2013-06-16   Kg       28       30     29.0
# ...        ...                  ...        ...  ...      ...      ...      ...
# 197156  197156    Garlic Dry Nepali 2021-05-13   Kg      100      120    110.0
# 197157  197157     Fish Fresh(Rahu) 2021-05-13   KG      270      280    275.0
# 197158  197158  Fish Fresh(Bachuwa) 2021-05-13   KG      225      235    230.0
# 197159  197159   Fish Fresh(Chhadi) 2021-05-13   KG      220      230    225.0
# 197160  197160  Fish Fresh(Mungari) 2021-05-13   KG      240      250    245.0
#
# ...

# %%
print(df.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 197156    False
# 197157    False
# 197158    False
# 197159    False
# 197160    False
# Length: 197161, dtype: bool

# %%
# remove duplicate
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#             SN            Commodity       Date Unit  Minimum  Maximum  Average
# 0            0   Tomato Big(Nepali) 2013-06-16   Kg       35       40     37.5
# 1            1  Tomato Small(Local) 2013-06-16   Kg       26       32     29.0
# 2            2           Potato Red 2013-06-16   Kg       20       21     20.5
# 3            3         Potato White 2013-06-16   Kg       15       16     15.5
# 4            4   Onion Dry (Indian) 2013-06-16   Kg       28       30     29.0
# ...        ...                  ...        ...  ...      ...      ...      ...
# 197156  197156    Garlic Dry Nepali 2021-05-13   Kg      100      120    110.0
# 197157  197157     Fish Fresh(Rahu) 2021-05-13   KG      270      280    275.0
# 197158  197158  Fish Fresh(Bachuwa) 2021-05-13   KG      225      235    230.0
# 197159  197159   Fish Fresh(Chhadi) 2021-05-13   KG      220      230    225.0
# 197160  197160  Fish Fresh(Mungari) 2021-05-13   KG      240      250    245.0
#
# ...

# %%
# finding relationship using correlation
df.corr()
# Out:
#                SN   Minimum   Maximum   Average
# SN       1.000000  0.137971  0.131620  0.134856
# Minimum  0.137971  1.000000  0.995061  0.998681
# Maximum  0.131620  0.995061  1.000000  0.998846
# Average  0.134856  0.998681  0.998846  1.000000

# %%
# scatter plot
df.plot(kind = 'scatter', x = 'Minimum', y = 'Average')
# Out:
# <AxesSubplot:xlabel='Minimum', ylabel='Average'>

# %%
# histogram
df["Minimum"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# convert dataframe to numpy
df.to_numpy()
# Out:
# array([[0, 'Tomato Big(Nepali)', Timestamp('2013-06-16 00:00:00'), ...,
#         35, 40, 37.5],
#        [1, 'Tomato Small(Local)', Timestamp('2013-06-16 00:00:00'), ...,
#         26, 32, 29.0],
#        [2, 'Potato Red', Timestamp('2013-06-16 00:00:00'), ..., 20, 21,
#         20.5],
#        ...,
#        [197158, 'Fish Fresh(Bachuwa)', Timestamp('2021-05-13 00:00:00'),
#         ..., 225, 235, 230.0],
#        [197159, 'Fish Fresh(Chhadi)', Timestamp('2021-05-13 00:00:00'),
#         ..., 220, 230, 225.0],
#        [197160, 'Fish Fresh(Mungari)', Timestamp('2021-05-13 00:00:00'),
#         ..., 240, 250, 245.0]], dtype=object)

# %%
# stastical summary of data
df.describe()
# Out:
#                   SN        Minimum        Maximum        Average
# count  197161.000000  197161.000000  197161.000000  197161.000000
# mean    98580.000000      85.423938      94.161284      89.792611
# std     56915.622549      77.058896      82.375858      79.619003
# min         0.000000       1.000000       6.000000       5.000000
# 25%     49290.000000      40.000000      45.000000      42.500000
# 50%     98580.000000      60.000000      70.000000      65.000000
# 75%    147870.000000     100.000000     110.000000     105.000000
# max    197160.000000    1800.000000    2000.000000    1900.000000

# %%
# transposing data
df.T
# Out:
#                         0                    1                    2       \
# SN                           0                    1                    2
# Commodity   Tomato Big(Nepali)  Tomato Small(Local)           Potato Red
# Date       2013-06-16 00:00:00  2013-06-16 00:00:00  2013-06-16 00:00:00
# Unit                        Kg                   Kg                   Kg
# Minimum                     35                   26                   20
# Maximum                     40                   32                   21
# Average                   37.5                 29.0                 20.5
#
#                         3                    4                    5       \
# SN                           3                    4                    5
# Commodity         Potato White   Onion Dry (Indian)        Carrot(Local)
# Date       2013-06-16 00:00:00  2013-06-16 00:00:00  2013-06-16 00:00:00
# Unit                        Kg                   Kg                   Kg
# ...

# %%
# selection by label-row
# locates by name
df.loc[0]
# Out:
# SN                             0
# Commodity     Tomato Big(Nepali)
# Date         2013-06-16 00:00:00
# Unit                          Kg
# Minimum                       35
# Maximum                       40
# Average                     37.5
# Name: 0, dtype: object

# %%
# selection by position
# locates by numerical index
df.iloc[0]
# Out:
# SN                             0
# Commodity     Tomato Big(Nepali)
# Date         2013-06-16 00:00:00
# Unit                          Kg
# Minimum                       35
# Maximum                       40
# Average                     37.5
# Name: 0, dtype: object

# %%
# mean calculation of numerical data only
df.mean()
# Out:
# /tmp/ipykernel_28282/2245948227.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# /tmp/ipykernel_28282/2245948227.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# SN         98580.000000
# Minimum       85.423938
# Maximum       94.161284
# Average       89.792611
# dtype: float64

# %%
# number of rows and column
df.shape
# Out:
# (197161, 7)

# %%
# column name
df.columns
# Out:
# Index(['SN', 'Commodity', 'Date', 'Unit', 'Minimum', 'Maximum', 'Average'], dtype='object')

# %%
# count number of null
df.isnull().sum()
# Out:
# SN           0
# Commodity    0
# Date         0
# Unit         0
# Minimum      0
# Maximum      0
# Average      0
# dtype: int64
